# %%
import os
import sync.sync as sync
import pickle
import get_camera_frame_times

# %%
mainPath = r"\\allen\programs\mindscope\workgroups\dynamicrouting\PilotEphys\Task 2 pilot\DRpilot_626791_20220815"

syncPath = glob.glob(os.path.join(mainPath, '*.h5'))[0] #assumes that sync file is the only .h5!
processedDataPath = os.path.join(mainPath,'processed')

cam_frames_path = os.path.join(processedDataPath, 'camera_frames.pkl')

face_json_path = glob.glob(os.path.join(mainPath,'Face_*.json'))[0]
beh_json_path = glob.glob(os.path.join(mainPath,'Behavior_*.json'))[0]
eye_json_path = glob.glob(os.path.join(mainPath,'Eye_*.json'))[0]

# %%
syncDataset = sync.Dataset(syncPath)

# %%
syncDataset.line_labels
# Out:
# ['barcode_ephys',
#  '',
#  'vsync_stim',
#  '',
#  'stim_photodiode',
#  'stim_running',
#  '',
#  '',
#  'beh_frame_received',
#  'eye_frame_received',
#  'face_frame_received',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'stim_running_opto',
#  'stim_trial_opto',
#  '',
#  '',
#  'beh_cam_frame_readout',
#  'face_cam_frame_readout',
#  '',
#  '',
#  'eye_cam_frame_readout',
#  '',
#  'beh_cam_exposing',
#  'face_cam_exposing',
#  'eye_cam_exposing',
#  '',
#  'lick_sensor']

# %%
# beh_json_path=r"D:\DR Pilot Data\DRpilot_626791_20220815\Behavior_20220815T112223.json"
# face_json_path=r"D:\DR Pilot Data\DRpilot_626791_20220815\Face_20220815T112223.json"
# eye_json_path=r"D:\DR Pilot Data\DRpilot_626791_20220815\Eye_20220815T112223.json"

# %%
# beh_frame_times=syncDataset.get_rising_edges('beh_frame_received')/100000
# face_frame_times=syncDataset.get_rising_edges('face_frame_received')/100000
# eye_frame_times=syncDataset.get_rising_edges('eye_frame_received')/100000

beh_frame_times=get_camera_frame_times.get_frame_exposure_times(syncDataset,beh_json_path)
face_frame_times=get_camera_frame_times.get_frame_exposure_times(syncDataset,face_json_path)
eye_frame_times=get_camera_frame_times.get_frame_exposure_times(syncDataset,eye_json_path)

# %%
camera_frame_times={
    'behavior':beh_frame_times,
    'face':face_frame_times,
    'eye':eye_frame_times,
}

with open(cam_frames_path, 'wb') as filepath:
    pickle.dump(camera_frame_times, filepath)

# %%
fig,ax=plt.subplots(1,1)
ax.hist(np.diff(beh_frame_times),100)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([2.74248e+05, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
# ...

# %%
main_paths = [
    r"\\allen\programs\mindscope\workgroups\dynamicrouting\PilotEphys\Task 2 pilot\DRpilot_626791_20220815",
    r"\\allen\programs\mindscope\workgroups\dynamicrouting\PilotEphys\Task 2 pilot\DRpilot_626791_20220816",
    r"\\allen\programs\mindscope\workgroups\dynamicrouting\PilotEphys\Task 2 pilot\DRpilot_626791_20220817",
    
    r"\\allen\programs\mindscope\workgroups\dynamicrouting\PilotEphys\Task 2 pilot\DRpilot_636766_20230123", 
    r"\\allen\programs\mindscope\workgroups\dynamicrouting\PilotEphys\Task 2 pilot\DRpilot_636766_20230124", 
    r"\\allen\programs\mindscope\workgroups\dynamicrouting\PilotEphys\Task 2 pilot\DRpilot_636766_20230125", 
    r"\\allen\programs\mindscope\workgroups\dynamicrouting\PilotEphys\Task 2 pilot\DRpilot_636766_20230126", 
    r"\\allen\programs\mindscope\workgroups\dynamicrouting\PilotEphys\Task 2 pilot\DRpilot_644864_20230130",
    r"\\allen\programs\mindscope\workgroups\dynamicrouting\PilotEphys\Task 2 pilot\DRpilot_644864_20230131", 
    r"\\allen\programs\mindscope\workgroups\dynamicrouting\PilotEphys\Task 2 pilot\DRpilot_644864_20230201", 
    r"\\allen\programs\mindscope\workgroups\np-exp\PilotEphys\Task 2 pilot\DRpilot_644864_20230202",
    r"\\allen\programs\mindscope\workgroups\np-exp\PilotEphys\Task 2 pilot\DRpilot_644866_20230207", 
    r"Y:\DRpilot_644866_20230208",
    r"Y:\DRpilot_644866_20230209",
    r"Y:\DRpilot_644866_20230210",
    r"Y:\DRpilot_644867_20230220",
    r"Y:\DRpilot_644867_20230221",
    r"Y:\DRpilot_644867_20230222",
    r"Y:\DRpilot_644867_20230223",
    r"Y:\DRpilot_649943_20230213", 
    r"Y:\DRpilot_649943_20230214",
    r"Y:\DRpilot_649943_20230215",
    r"Y:\DRpilot_649943_20230216",   
]

# %%
for mainPath in main_paths:
    syncPath = glob.glob(os.path.join(mainPath, '*.h5'))[0] #assumes that sync file is the only .h5!
    processedDataPath = os.path.join(mainPath,'processed')
    cam_frames_path = os.path.join(processedDataPath, 'camera_frames.pkl')
    face_json_path = glob.glob(os.path.join(mainPath,'Face_*.json'))[0]
    beh_json_path = glob.glob(os.path.join(mainPath,'Behavior_*.json'))[0]
    eye_json_path = glob.glob(os.path.join(mainPath,'Eye_*.json'))[0]
    
    syncDataset = sync.Dataset(syncPath)
    
#     beh_frame_times=syncDataset.get_rising_edges('beh_frame_received')/100000
#     face_frame_times=syncDataset.get_rising_edges('face_frame_received')/100000
#     eye_frame_times=syncDataset.get_rising_edges('eye_frame_received')/100000

    beh_frame_times=get_camera_frame_times.get_frame_exposure_times(syncDataset,beh_json_path)
    face_frame_times=get_camera_frame_times.get_frame_exposure_times(syncDataset,face_json_path)
    eye_frame_times=get_camera_frame_times.get_frame_exposure_times(syncDataset,eye_json_path)
    
    camera_frame_times={
        'behavior':beh_frame_times,
        'face':face_frame_times,
        'eye':eye_frame_times,
    }

    with open(cam_frames_path, 'wb') as filepath:
        pickle.dump(camera_frame_times, filepath)

# %%
beh_frame_times
# Out:
# array([], dtype=float64)
